# %%
#*****************************HTML QUIZ***********************************************
hquiz =[
    {
        "Q )":"What does HTML stand for? : ",
        "op)":["Home Tool Markup Language","Hyper Text Markup Language","HyperLink Mark up Language","HyperLink and Text Markup Language"],
        "ans":"b",
    },
    
    {
        "Q )":"Choose the correct HTML element for the largest heading: ",
        "op)":['<h1>','<h3>','<h6>','<h4>'],
        "ans":"a",
    },
    
    {
        "Q )":"Which character is used to indicate an end tag?: " ,
        "op)":['^','<','/','*'],
        "ans":"c",
    },
    
    {
        "Q )":"How can you open a link in a new tab/browser window?:" ,
        "op)":['<a href="url" new >','<a href="url" target="_blank">','<a href="url" target="new">','<a href="url" targets="_blanks">'],
        "ans":"b",
    },
    
    {
        "Q )":"Which of these elements are all <table> elements?: " ,
        "op)":['<table><tr><tt>','<table><td><tr>','<table><th><td>','<table><tr><td>'],
        "ans":"d",
    },
    
    {
        "Q )":"How can you make a numbered list?:" ,
        "op)":['<ol>','<li>','<ul>','<list>'],
        "ans":"a",
    },
    
    {
        "Q )":"What is the correct HTML for making a text input field?: " ,
        "op)":['<input type="textfield">','<input type="text">','<input type="field">','<textinput type="textfield">'],
        "ans":"b",
    },
    
    {
        "Q )":"In HTML,which attribute is used an input field must be filled out?: :" ,
        "op)":['validate','placeholder','get','required'],
        "ans":"d",
    },
    
    {
        "Q )":"Type Of Tag In Html:",
        "op)":['1','3','2','4'],
        "ans":"c",
    },
    
    {
        "Q )":"What is the correct HTML element for inserting a line break?:" ,
        "op)":['<break>','<rb>','<br>','<hr>'],
        "ans":"c",
    }
]

#*****************************CSS QUIZ***********************************************

cquiz =[
    {
        "Q )":"What does CSS stand for? : ",
        "op)":['Computer Style Sheet','Colourful Style Sheet','Casecading Style Sheet','Creative Style Sheet'],
        "ans":"c",
    },
    
    {
        "Q )":"Which HTML tag is used to define an internal css?:",
        "op)":['styles','style','font','css'],
        "ans":"b",
    },
    
    {
        "Q )":'Which is the correct CSS syntax?:' ,
        "op)":['{body:color="red;"}','{body;color="red;"}','body:color="red;"','body{color:red;}'],
        "ans":"d",
    },
    
    {
        "Q )":"'Which property is used to change the font color?:'" ,
        "op)":['color','background-color','bgcolor','background'],
        "ans":"a",
    },
    
    {
        "Q )":"Which property is used to change the background color?:" ,
        "op)":['color','background-color','bgcolor','background'],
        "ans":"b",
    },
    
    {
        "Q )":"Which CSS property controls the text size?:" ,
        "op)":['font-style','text-style','font-size','text-size'],
        "ans":"c",
    },
    
    {
        "Q )":"Which HTML attribute is used to define inline styles?:" ,
        "op)":['styles','style','font','css'],
        "ans":"b",
    },
    
    {
        "Q )":"How do you display hyperlinks without an underline?:" ,
        "op)":['a{text-decoration:no-underline;}','a{underline:none;}','a{text-decoration:none}','a{decoration:no-nderline}'],
        "ans":"c",
    },
    
    {
        "Q )":"Which property is used to change the font of an element?:" ,
        "op)":['font-style','font-family','font-size','font-weight'],
        "ans":"b",
    },
    
    {
        "Q )":"How do you make the text bold?:" ,
        "op)":['font-style','font-family','font-size','font-weight'],
        "ans":"d",
    }
]


#*****************************PYTHON QUIZ***********************************************

pquiz =[
    {
        "Q )":"Python Language Created By : ",
        "op)":["Dennis Ritchie","Guido van Rossum","James Gosling","Brendan Eich"],
        "ans":"b",
    },
    
    {
        "Q )":"Python Language Created in : ",
        "op)":["1990","2010","2019","1991"],
        "ans":"d",
    },
    
    {
        "Q )":"Which is immutable :" ,
        "op)":["Tuple","List ","dictionary","None Of These"],
        "ans":"a",
    },
    
    {
        "Q )":"Which is mutable :" ,
        "op)":["Tuple","List ","String","None Of These"],
        "ans":"b",
    },
    
    {
        "Q )":"What is The Output Of Following Code :\n print(2+2*2)" ,
        "op)":["2","8 ","6","4"],
        "ans":"c",
    },
    
    {
        "Q )":"What is the output of the following code? :\n str =python \n print (str[1:3])" ,
        "op)":["pyt","py","th","yt"],
        "ans":"d",
    },
    
    {
        "Q )":"What is the data type of print(type(10)? :" ,
        "op)":["int","String","Float","List"],
        "ans":"a",
    },
    
    {
        "Q )":"What is the data type of print(type(10.6)? :" ,
        "op)":["int","String","Float","List"],
        "ans":"c",
    },
    
    {
        "Q )":"Which Function To Check The Length Of List or String :" ,
        "op)":["length","len","int","str"],
        "ans":"b",
    },
    
    {
        "Q )":"What is the output of the following code :\n x = 6,y = 2, print(x // y)" ,
        "op)":["0","3.0","12","3"],
        "ans":"d",
    }
]



Name=input("Enter Your Name\n")
print("**********************************QUIZ MADE BY MUHAMMAD ZUBAIR MINHAS************************\n")

again ='y'

while (again=='y' or again=='Y'):
    i=0
    mar=0
    quiz=''
    sel=input("\n1 For  HTML QUIZ \n2 For PYTHON QUIZ \n3 For CSS QUIZ \n SELECT  QUIZ :")
    
    if(sel=='1'):
        print("=============================WELCOME ",Name.upper() ,"IN HTML LANGUAGE QUIZ===================================\n")
        quiz=hquiz
        
    elif(sel=='2'):
        print("=============================WELCOME ",Name.upper() ,"IN PYTHON LANGUAGE QUIZ===================================\n")
        quiz=pquiz
        
    elif(sel=='3'):
        print("=============================WELCOME ",Name.upper() ,"IN CSS LANGUAGE QUIZ===================================\n")
        quiz=cquiz
    
    else:
        print("PLEASE SELECT CORRECT OPEATION :")
            
    for question in quiz:
        i=i+1
        print("Q No:",i,")",question["Q )"])
        print("a):",question["op)"][0])
        print("b):",question["op)"][1])
        print("c):",question["op)"][2])
        print("d):",question["op)"][3])
        inp=input("\nEnter  Option :")
        if inp.lower() == question["ans"]:
            print("Your Answer Is Correct\n")
            mar +=1
            print("***********************")
        else:
            print("Your Answer Is Incorrect")
            print("Correct Anwer :",question["ans"],"\n")
            print("***********************")
            
    print("Quiz Completed\nYOUR NAME :"+Name+"\nYour Total Score :",mar)
    again=input("IF YOU PLAY TRY AGAIN THEN ENTER Y OR y otherWise Enter Any Key :  ")
# Out:
# Enter Your Name
# zubair
# **********************************QUIZ MADE BY MUHAMMAD ZUBAIR MINHAS************************
#
#
# 1 For  HTML QUIZ
# 2 For PYTHON QUIZ
# 3 For CSS QUIZ
#  SELECT  QUIZ :1
# =============================WELCOME  ZUBAIR IN HTML LANGUAGE QUIZ===================================
#
# Q No: 1 ) What does HTML stand for? :
# a): Home Tool Markup Language
# b): Hyper Text Markup Language
# c): HyperLink Mark up Language
# d): HyperLink and Text Markup Language
#
# Enter  Option :b
# Your Answer Is Correct
#
# ***********************
# Q No: 2 ) Choose the correct HTML element for the largest heading:
# a): <h1>
# b): <h3>
# c): <h6>
# d): <h4>
#
# Enter  Option :a
# Your Answer Is Correct
#
# ***********************
# Q No: 3 ) Which character is used to indicate an end tag?:
# a): ^
# b): <
# c): /
# d): *
#
# Enter  Option :c
# Your Answer Is Correct
#
# ***********************
# Q No: 4 ) How can you open a link in a new tab/browser window?:
# ...
